# %% [markdown]
# Import the necessary Libraries.Read diabetic patients file. And see the header of the file.

# %%
import pandas as pd
import numpy as np

# %%
records=pd.read_csv(r"Diabetes_record_linear.csv")

# %%
print(records.head())
# Out:
#    BMI   BP  Cholesterol  LDL  Target
# 0   26   99          165   75     524
# 1   39   65          285   92     717
# 2   34   70          226   77     655
# 3   31  114          274   63     732
# 4   21   96          198   68     606

# %%
print(records.isnull().sum())
# Out:
# BMI            0
# BP             0
# Cholesterol    0
# LDL            0
# Target         0
# dtype: int64

# %% [markdown]
# Select the features (X) and the actual output (y) from the dataset. Scale the Features because their is variation between the feature.

# %%
y=records["Target"]
x=records.drop(columns=["Target"])
train_mean=x.mean()
stand_dev=x.std()
train_normilization=(x-train_mean)/stand_dev
print(train_normilization.head())
# Out:
#         BMI        BP  Cholesterol       LDL
# 0 -0.405526  0.496449    -1.369036 -1.120368
# 1  1.587606 -1.438138     1.234932 -0.713657
# 2  0.821017 -1.153640    -0.045352 -1.072520
# 3  0.361063  1.349944     0.996235 -1.407458
# 4 -1.172115  0.325750    -0.652945 -1.287837

# %% [markdown]
# Compute cost function. Below there are two ways given one for better understanding but it was very slow so to speed this up we use the vectorized version of this

# %%
def cost_fun(x,y,w,b):
    summation=0
    m=x.shape[0]
    w_x=np.dot(x,w)+b
    cost=(w_x-y)**2
    summation=np.sum(cost)/(2*m)
    return summation
# Cost Function
# def cost_fun(x,y,w,b):
#     summation=0
#     m=x.shape[0]
#     for i in range(m):
#         w_x=np.dot(x[i],w)+b
#         cost=(w_x-y[i])**2
#         summation+=cost/(2*m)
#     return summation

# %% [markdown]
# Calculate derivation: the given block have two types of codes. if we use the commented part we use the vectorized version because -> Instead of running millions slow lines of Python loop code, NumPy sends the entire matrix block to highly optimized C-code background libraries. The computer calculates the entire gradient step in a single operation, allowing your 100,000 iterations to finish in under a second.

# %%
def derivative(x, y, w, b):
    m, n = x.shape
    f_wb = np.dot(x, w) + b
    err = f_wb - y
    dj_dw = np.dot(x.T, err) / m
    dj_db = np.sum(err) / m
    
    return dj_dw, dj_db

# def derivative(x,y,w,b):
#     m,n=x.shape
#     cost_w=np.zeros((n,))
#     cost_b=0
#     for i in range(m):
#         w_x=(np.dot(x[i],w)+b)-y[i]
#         for j in range(n):
#             cost_w[j]=cost_w[j]+w_x*x[i,j]
#         cost_b+=(w_x)
#     cost_w=cost_w/m
#     cost_b=cost_b/m
#     return cost_w,cost_b

# %% [markdown]
# Compute gradient descent

# %%
def gradient_descent(x,y,w,b,num_iter,alpha,derivative_function,cost_function):
    for i in range(num_iter+1):
        gradient_w,gradient_b=derivative_function(x,y,w,b)
        compute_cost=cost_function(x,y,w,b)
        w=w-alpha*gradient_w
        b=b-alpha*gradient_b
        if i % 10000 == 0:
            print(f"Iteration {i}: Cost={compute_cost:.2f}")
    return w,b

# %% [markdown]
# Prediction and compare the predicited and actual values

# %%
x = train_normilization.values
y = y.values.reshape(-1)

num_iter = 30000
alpha = 0.001

weight = np.array([0, 0, 0, 0])
bias = 0

print("Linear Regression in progress...........")

w, b = gradient_descent(
    x, y, weight, bias,
    num_iter, alpha,
    derivative, cost_fun
)

m = x.shape[0]

for i in range(m):
    prediction = np.dot(w, x[i]) + b
    print(f"prediction: {prediction:.2f} target: {y[i]}")
# Predictions
predictions = np.dot(x, w) + b
# Out:
# Linear Regression in progress...........
# Iteration 0: Cost=249929.12
# Iteration 10000: Cost=425.96
# Iteration 20000: Cost=425.96
# Iteration 30000: Cost=425.96
# prediction: 690.17 target: 729
# prediction: 684.84 target: 712
# prediction: 858.42 target: 804
# prediction: 639.69 target: 598
# prediction: 673.55 target: 656
# prediction: 783.20 target: 789
# prediction: 800.02 target: 825
# prediction: 797.83 target: 785
# prediction: 616.43 target: 618
# prediction: 770.77 target: 749
# prediction: 505.44 target: 489
# prediction: 661.00 target: 613
# prediction: 653.47 target: 623
# prediction: 876.02 target: 845
# prediction: 773.55 target: 743
# prediction: 675.68 target: 707
# prediction: 707.10 target: 668
# prediction: 833.97 target: 912
# prediction: 763.54 target: 784
# prediction: 766.19 target: 778
# prediction: 666.92 target: 642
# prediction: 601.71 target: 613
# prediction: 800.43 target: 782
# prediction: 651.88 target: 656
# prediction: 692.09 target: 768
# prediction: 716.54 target: 714
# prediction: 631.59 target: 665
# prediction: 762.32 target: 749
# prediction: 619.49 target: 619
# prediction: 710.49 target: 757
# prediction: 773.25 target: 761
# prediction: 780.33 target: 839
# prediction: 632.15 target: 647
# prediction: 890.78 target: 886
# prediction: 734.90 target: 760
# prediction: 643.35 target: 667
# prediction: 672.67 target: 680
# prediction: 756.83 target: 716
# prediction: 643.34 target: 614
# prediction: 650.09 target: 641
# prediction: 867.13 target: 878
# prediction: 819.81 target: 840
# prediction: 630.60 target: 633
# prediction: 622.34 target: 580
# prediction: 574.98 target: 584
# prediction: 686.63 target: 705
# prediction: 561.39 target: 584
# prediction: 746.36 target: 778
# prediction: 776.11 target: 811
# prediction: 802.09 target: 826
# prediction: 680.87 target: 678
# prediction: 730.78 target: 678
# prediction: 583.66 target: 587
# prediction: 775.11 target: 783
# prediction: 554.15 target: 556
# prediction: 694.46 target: 660
# prediction: 820.28 target: 785
# prediction: 655.06 target: 686
# prediction: 606.13 target: 606
# prediction: 792.91 target: 811
# prediction: 812.24 target: 814
# prediction: 656.08 target: 658
# prediction: 707.31 target: 733
# prediction: 788.23 target: 781
# prediction: 672.72 target: 672
# prediction: 683.93 target: 671
# prediction: 645.93 target: 635
# prediction: 797.25 target: 793
# prediction: 651.97 target: 653
# prediction: 587.48 target: 569
# prediction: 647.30 target: 687
# prediction: 763.38 target: 747
# prediction: 558.57 target: 560
# prediction: 769.51 target: 752
# prediction: 662.33 target: 701
# prediction: 735.23 target: 743
# prediction: 623.45 target: 652
# prediction: 820.44 target: 784
# prediction: 888.66 target: 902
# prediction: 682.06 target: 703
# prediction: 743.49 target: 747
# prediction: 766.84 target: 804

# %% [markdown]
# Lets computes the R^2 Score. The code determines how closely your machine learning model's predictions align with your actual data points.

# %%
# R²
ss_res = np.sum((y - predictions) ** 2)
ss_tot = np.sum((y - np.mean(y)) ** 2)

r2 = 1 - (ss_res / ss_tot)

print("R² Score:", r2)
print("R² Percentage:", r2 * 100, "%")
# Out:
# R² Score: 0.9167745052247213
# R² Percentage: 91.67745052247213 %

# %% [markdown]
# User INPUT (user enter the data and model predicts the targets value)

# %%
BMI = float(input("Enter BMI: "))
BP = float(input("Enter BP: "))
Cholesterol = float(input("Enter Cholesterol: "))
LDL = float(input("Enter LDL: "))

new_patient = pd.DataFrame({
    "BMI": [BMI],
    "BP": [BP],
    "Cholesterol": [Cholesterol],
    "LDL": [LDL]
})

# Normalize using training mean and standard deviation
new_patient_normalized = (
    new_patient - train_mean
) / stand_dev

# Convert to NumPy
new_patient_record = new_patient_normalized.values.flatten()

# Prediction
prediction = np.dot(w, new_patient_record) + b

print(f"\nPredicted Target: {prediction:.2f}")
# Out:
# Predicted Target: 546.29
